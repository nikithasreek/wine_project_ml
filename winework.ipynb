# %%
import pickle

# %%
fixed_acidity= float(input('fixed acidity: '))
volatile_acidity= float(input('volatile acidity: '))
citric_acid= float(input('citric acid: '))
residual_sugar= float(input('residual sugar: '))
chlorides= float(input('chlorides: '))
free_sulfur_dioxide= float(input('free sulfur dioxide: '))
total_sulfur_dioxide= float(input('total sulfur dioxide: '))
density= float(input('density: '))
pH= float(input('pH: '))
sulphates= float(input('sulphates: '))
alcohol= float(input('alcohol: '))

# %%
col=[[fixed_acidity, volatile_acidity, citric_acid, residual_sugar,
       chlorides, free_sulfur_dioxide, total_sulfur_dioxide, density,
       pH, sulphates, alcohol]]

# %%
col
# Out:
# [[4.0, 4.0, 4.0, 44.0, 4.0, 44.0, 4.0, 44.0, 4.0, 4.0, 44.0]]

# %%
scalerstd=pickle.load(open('stdscaler.sav','rb'))

# %%
col1=scalerstd.transform(col)
col1
# Out:
# c:\Users\nmnni\OneDrive\Desktop\datascience luminar\project wine\PROJECT_WINE\venv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([[-3.14977268e+00,  3.55540305e+01,  4.08258230e+01,
#          8.65198812e+00,  2.74172539e+02,  9.54826991e-01,
#         -2.54068736e+00,  1.53087311e+04,  5.47988738e+00,
#          3.26327021e+01,  2.54329863e+01]])

# %%
modelrf=pickle.load(open('rfmodel.sav','rb'))

# %%
prediction = modelrf.predict(col1)
print(prediction)
# Out:
# [6]
